# %% [markdown]
# # Welcome to Deep Learning for Image Analysis with PyTorch
#
# Fernando Cervantes Sanchez
#
# Systems Analyst I - Imaging Applications group, JAX Research IT
#
# (slack) @fernando.cervantes
#
# (email) fernando.cervantes@jax.org

# %% [markdown]
# Workshop Day 1 outcomes
#
# *   Overview of the workflow of a Deep Learning (DL) project from development to production
# *   Learn basic manipulation and mathematic operations on PyTorch tensors
# *   Review and understand the architecture of classic and recent DL models
# *   Define training process of a DL model as an optimization problem

# %% [markdown]
# # 1.- Overview of the workflow of a Deep Learning (DL) project, from development to production

# %% [markdown]
# # Machine learning
# Is a field that studies methods for building models capable of performing tasks that are considered labor-intesive and/or time-consuming.
#
# These models learn to perform that task through some kind of training.
#
# Most of the machine learning methods use statistical learning to build their models, therefore the algorithms and strategies used are mostly based on statistical theory.

# %% [markdown]
# In computer vision, the tasks or problems involve image clustering, classification, objects recognition and localization, semantic segmentation, image restoration, style transfering, denoising, super resolution, etc.

# %% [markdown]
# ![3D reconstruction](https://upload.wikimedia.org/wikipedia/commons/6/6d/Synthesizing_3D_Shapes_via_Modeling_Multi-View_Depth_Maps_and_Silhouettes_With_Deep_Generative_Networks.png)
# ![Super resolution](https://upload.wikimedia.org/wikipedia/commons/b/be/Super-resolution_example_closeup.png)

# %% [markdown]
# ## Begin with a task/problem and describe it as a function

# %% [markdown]
# Usually it will have the shape of $f_\theta(x) = y$, and in computer vision, $x$ is typically an image or a video.
#
# And $f_\theta(x)$ can be as simple or as complex as the problem requires.

# %% [markdown]
# ---
#
# ## Deep Learning (DL) models
#
# Models that construct knowledge in a hierarchical manner are considered **deep models**.
# The most common type of deep learning models are *artificial neural networks*.
#
# Artifical neural networks are layered models that use the output of a layer as the input of a subsequent layer.
#
# What determines the complexity and accuracy of neural networks to perform a certain tasks are their **architecture** and **parameters $\theta$**.
#
# ![ANN](https://www.mdpi.com/applsci/applsci-09-05507/article_deploy/html/images/applsci-09-05507-g003-550.jpg)
#
# The architecture of a neural network also help us to represent the model, implement it in a programming language, and share trained models.

# %% [markdown]
# A drawback of deep learning models, and artificial neural networks in general, is their lack of explainability.
#
# However, there are recent techniques that address that problem and try to give some explanation to how a DL model made its prediction.

# %% [markdown]
# ### Examples of popular DL models in computer vision

# %% [markdown]
# Inception v3 for image classification
# ![InceptionV3](https://cloud.google.com/static/tpu/docs/images/inceptionv3onc--oview.png)

# %% [markdown]
# U-Net for cell segmentation
# ![U-Net](https://lmb.informatik.uni-freiburg.de/people/ronneber/u-net/u-net-architecture.png)

# %% [markdown]
# ## Train the model to learn the parameter's values

# %% [markdown]
# ![Training_loop.png](data:image/png;base64,...)

# %% [markdown]
# ## Evaluate the model performance

# %% [markdown]
# ![Object detection and localization](https://upload.wikimedia.org/wikipedia/commons/2/2d/Intersection_over_Union_-_object_detection_bounding_boxes.jpg)

# %% [markdown]
# ## Prepare our model for production
#
# After training and evaluating our model, we can fix its parameters and have a version that behaves good enough in the task it was trained to carry out.
#
# Some options to deliver our trained model are
#
#
# *   Containerize it for use in HPC (Sumner, Winter)
# *   Migrate it to a Cloud platform for external use
# *   Share the code to build the model (github), along the pre-trained parameters (bucket, drive)

# %% [markdown]
# $\hat{y} = f_{\theta*}(x)$, where $x$ is a new real-world sample
